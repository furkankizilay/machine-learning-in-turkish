# %% [markdown]
# # Machine Learning 401

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# * Amaç iki sınıf arasındaki ayrımın optimum olmasını sağlayacak hiper-düzlemi bulmaktır.

# %% [markdown]
# * Doğrusal SVM
# ![Screenshot%202021-10-10%20175710.png](attachment:Screenshot%202021-10-10%20175710.png)

# %% [markdown]
# * Doğrusal Olmayan SVM
# ![Screenshot%202021-10-10%20175700.png](attachment:Screenshot%202021-10-10%20175700.png)

# %% [markdown]
# ### Model ve Tahmin

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score,roc_auc_score, roc_curve,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
import warnings
warnings.filterwarnings("ignore", category = DeprecationWarning)
warnings.filterwarnings("ignore", category = FutureWarning)

# %%
df = pd.read_csv("diabetes.csv")
y = df["Outcome"]
X = df.drop(["Outcome"], axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
svm_model = SVC(kernel = "linear").fit(X_train, y_train)

# %%
svm_model
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm_model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7445887445887446

# %% [markdown]
# ### Model Tuning

# %%
svm = SVC()

# %%
svm_params = {"C" : np.arange(1,10), "kernel" : ["linear","rbf"]} # c ceza parametresi

# %%
svm_cv_model = GridSearchCV(svm, svm_params, cv = 5, n_jobs = -1, verbose = 2).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits

# %%
svm_cv_model.best_score_
# Out:
# 0.7839044652128765

# %%
svm_cv_model.best_params_
# Out:
# {'C': 2, 'kernel': 'linear'}

# %%
# final modeli

# %%
svm_tuned = SVC(C = 2, kernel = "linear").fit(X_train, y_train)

# %%
y_pred = svm_tuned.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7445887445887446
